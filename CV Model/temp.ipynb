# %%
import os
import torch
import torchvision
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision.models.detection import maskrcnn_resnet50_fpn
from torchvision.transforms.functional import to_tensor
from torchvision.io import read_image
from torchvision.ops import masks_to_boxes
from torchvision.utils import draw_bounding_boxes, draw_segmentation_masks
from engine import train_one_epoch, evaluate
import matplotlib.pyplot as plt
import cv2
import numpy as np
import datetime

# %%
# os.environ["CUDA_LAUNCH_BLOCKING"] = "1"

# %%
class ImageDataset(Dataset):
    def __init__(self, image_folder='rgbd-dataset\\food_can\\'):
        self.image_folder = image_folder
        self.image_info = []
        
        for filename in os.listdir(image_folder):
            if filename.endswith('.png') and not filename.endswith('mask.png') and not filename.endswith('depth.png'):
                image_path = os.path.join(image_folder, filename)
                mask_path = image_path.replace('.png', '_mask.png')
                # print(f"Image_path: {image_path}\nMask_path: {mask_path}")
                self.image_info.append({'image': image_path, 'mask': mask_path})

    def __len__(self):
        return len(self.image_info)
    
    def __getitem__(self, idx):
        image_path = self.image_info[idx]['image']
        mask_path = self.image_info[idx]['mask']
        
        image = read_image(image_path).to(torch.float32)  # Convert image to PyTorch tensor
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)  # Load mask using OpenCV
        mask_tensor = torch.tensor(mask > 127, dtype=torch.uint8)  # Convert mask to PyTorch tensor

        # Ensure we have a non-singleton dimension before squeezing
        if mask_tensor.dim() > 0 and mask_tensor.size(0) == 1:
            mask_tensor = mask_tensor.squeeze(0)

        # Use cv2.findContours to get bounding box from the mask
        contours, _ = cv2.findContours(mask_tensor.numpy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        if contours:
            # Get the bounding box for the largest contour
            x, y, w, h = cv2.boundingRect(contours[0])
            boxes = torch.tensor([[x, y, x+w, y+h]], dtype=torch.float32)
        else:
            # If no contours are found, provide a dummy box
            boxes = torch.tensor([[0, 0, 1, 1]], dtype=torch.float32)
        
        target = {
        'boxes': boxes,
        'labels': torch.tensor([1], dtype=torch.int64), # For example, '2' for cans
        'masks': mask_tensor.unsqueeze(0)
                }
        return image, target

# %%
def custom_collate_fn(batch):
    images = [item[0] for item in batch]
    targets = [item[1] for item in batch]
    return images, targets


def create_model(num_classes):
    model = maskrcnn_resnet50_fpn(pretrained=True)
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    
    model.roi_heads.box_predictor = torchvision.models.detection.faster_rcnn.FastRCNNPredictor(in_features, num_classes)
    in_features_mask = model.roi_heads.mask_predictor.conv5_mask.in_channels
    
    hidden_layer = 256
    
    model.roi_heads.mask_predictor = torchvision.models.detection.mask_rcnn.MaskRCNNPredictor(in_features_mask, hidden_layer, num_classes)
    return model

def train_model():
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Using {torch.cuda.get_device_name(device)}")

    dataset = ImageDataset()
    model = create_model(2)  # For background, can, others
    model.to(device)

    train_size = int(0.8 * len(dataset))
    test_size = len(dataset) - train_size
    train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

    train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True, collate_fn=custom_collate_fn)
    test_loader = DataLoader(test_dataset, batch_size=8, shuffle=False)

    optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9, weight_decay=0.0005)
    lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)

    num_epochs = 10
    for epoch in range(num_epochs):
        train_one_epoch(model, optimizer, train_loader, device, epoch, print_freq=10)
        lr_scheduler.step()
        torch.save(model.state_dict(), f'model_epoch{epoch}.pth')

    torch.save(model.state_dict(), 'final_model.pth')
    evaluate(model, test_loader, device=device)

def load_and_test_model(model_path):
    model = create_model(2)
    model.load_state_dict(torch.load(model_path))
    model.eval()
    dataset = ImageDataset()
    sample_image, target = dataset[0]
    prediction = model([sample_image.to(model.device)])[0]
    print(prediction)

# %%
train_model()
load_and_test_model('final_model.pth')
# Out:
# Using NVIDIA GeForce RTX 4070
# c:\Users\Varadh\Desktop\NEU\CS5335-Robotic-Science-and-Systems\Project\CS5335-4610-Project\.venv\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\Varadh\Desktop\NEU\CS5335-Robotic-Science-and-Systems\Project\CS5335-4610-Project\.venv\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MaskRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=MaskRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch: [0]  [  0/478]  eta: 0:13:08  lr: 0.000003  loss: 205.8944 (205.8944)  loss_classifier: 3.2452 (3.2452)  loss_box_reg: 0.5106 (0.5106)  loss_mask: 190.0376 (190.0376)  loss_objectness: 10.9530 (10.9530)  loss_rpn_box_reg: 1.1480 (1.1480)  time: 1.6503  data: 0.0926  max mem: 6740
# Epoch: [0]  [ 10/478]  eta: 0:06:14  lr: 0.000024  loss: 32.6096 (51.6741)  loss_classifier: 0.2835 (0.8179)  loss_box_reg: 0.4287 (0.4483)  loss_mask: 24.4254 (42.2699)  loss_objectness: 5.7762 (7.4137)  loss_rpn_box_reg: 0.6743 (0.7244)  time: 0.7995  data: 0.0867  max mem: 6906
# Epoch: [0]  [ 20/478]  eta: 0:05:45  lr: 0.000045  loss: 11.8524 (30.8504)  loss_classifier: 0.2778 (0.5632)  loss_box_reg: 0.3815 (0.3560)  loss_mask: 6.5951 (23.8839)  loss_objectness: 5.1585 (5.5099)  loss_rpn_box_reg: 0.4349 (0.5374)  time: 0.7097  data: 0.0843  max mem: 6906
# Epoch: [0]  [ 30/478]  eta: 0:05:32  lr: 0.000066  loss: 4.7056 (22.1612)  loss_classifier: 0.2722 (0.5077)  loss_box_reg: 0.2877 (0.3452)  loss_mask: 1.7535 (16.7122)  loss_objectness: 0.8446 (4.2152)  loss_rpn_box_reg: 0.1098 (0.3809)  time: 0.7115  data: 0.0803  max mem: 6908
# Epoch: [0]  [ 40/478]  eta: 0:05:22  lr: 0.000087  loss: 1.6977 (17.1391)  loss_classifier: 0.3560 (0.4617)  loss_box_reg: 0.2038 (0.3079)  loss_mask: 0.7032 (12.7937)  loss_objectness: 0.1846 (3.2826)  loss_rpn_box_reg: 0.0148 (0.2932)  time: 0.7184  data: 0.0772  max mem: 6908
# Epoch: [0]  [ 50/478]  eta: 0:05:14  lr: 0.000108  loss: 1.0698 (13.9663)  loss_classifier: 0.2551 (0.4189)  loss_box_reg: 0.1584 (0.2735)  loss_mask: 0.5876 (10.3881)  loss_objectness: 0.0395 (2.6473)  loss_rpn_box_reg: 0.0069 (0.2386)  time: 0.7197  data: 0.0769  max mem: 6909
# Epoch: [0]  [ 60/478]  eta: 0:05:05  lr: 0.000129  loss: 0.8855 (11.8055)  loss_classifier: 0.2267 (0.3844)  loss_box_reg: 0.1224 (0.2489)  loss_mask: 0.4605 (8.7545)  loss_objectness: 0.0246 (2.2171)  loss_rpn_box_reg: 0.0061 (0.2006)  time: 0.7196  data: 0.0784  max mem: 6911
# Epoch: [0]  [ 70/478]  eta: 0:04:57  lr: 0.000150  loss: 0.6184 (10.2247)  loss_classifier: 0.0796 (0.3394)  loss_box_reg: 0.1163 (0.2315)  loss_mask: 0.3762 (7.5721)  loss_objectness: 0.0182 (1.9086)  loss_rpn_box_reg: 0.0051 (0.1731)  time: 0.7199  data: 0.0784  max mem: 6911
# Epoch: [0]  [ 80/478]  eta: 0:04:49  lr: 0.000171  loss: 0.5092 (9.0188)  loss_classifier: 0.0581 (0.3049)  loss_box_reg: 0.1029 (0.2160)  loss_mask: 0.3009 (6.6700)  loss_objectness: 0.0174 (1.6755)  loss_rpn_box_reg: 0.0054 (0.1524)  time: 0.7206  data: 0.0768  max mem: 6911
# Epoch: [0]  [ 90/478]  eta: 0:04:42  lr: 0.000192  loss: 0.4282 (8.0718)  loss_classifier: 0.0383 (0.2749)  loss_box_reg: 0.0957 (0.2004)  loss_mask: 0.2710 (5.9669)  loss_objectness: 0.0169 (1.4934)  loss_rpn_box_reg: 0.0051 (0.1362)  time: 0.7224  data: 0.0762  max mem: 6911
# Epoch: [0]  [100/478]  eta: 0:04:35  lr: 0.000213  loss: 0.4366 (7.3217)  loss_classifier: 0.0369 (0.2525)  loss_box_reg: 0.0870 (0.1900)  loss_mask: 0.2820 (5.4094)  loss_objectness: 0.0124 (1.3465)  loss_rpn_box_reg: 0.0046 (0.1233)  time: 0.7267  data: 0.0765  max mem: 6911
# Epoch: [0]  [110/478]  eta: 0:04:27  lr: 0.000233  loss: 0.3836 (6.6941)  loss_classifier: 0.0369 (0.2328)  loss_box_reg: 0.0846 (0.1802)  loss_mask: 0.2494 (4.9419)  loss_objectness: 0.0108 (1.2264)  loss_rpn_box_reg: 0.0052 (0.1128)  time: 0.7278  data: 0.0771  max mem: 6911
# Epoch: [0]  [120/478]  eta: 0:04:20  lr: 0.000254  loss: 0.3288 (6.1647)  loss_classifier: 0.0278 (0.2156)  loss_box_reg: 0.0696 (0.1704)  loss_mask: 0.2040 (4.5491)  loss_objectness: 0.0074 (1.1255)  loss_rpn_box_reg: 0.0065 (0.1040)  time: 0.7250  data: 0.0768  max mem: 6911
# Epoch: [0]  [130/478]  eta: 0:04:13  lr: 0.000275  loss: 0.2762 (5.7155)  loss_classifier: 0.0258 (0.2013)  loss_box_reg: 0.0636 (0.1625)  loss_mask: 0.1663 (4.2151)  loss_objectness: 0.0053 (1.0401)  loss_rpn_box_reg: 0.0056 (0.0965)  time: 0.7213  data: 0.0754  max mem: 6911
# Epoch: [0]  [140/478]  eta: 0:04:05  lr: 0.000296  loss: 0.2452 (5.3274)  loss_classifier: 0.0245 (0.1886)  loss_box_reg: 0.0582 (0.1545)  loss_mask: 0.1573 (3.9276)  loss_objectness: 0.0040 (0.9667)  loss_rpn_box_reg: 0.0049 (0.0900)  time: 0.7196  data: 0.0757  max mem: 6911
# Epoch: [0]  [150/478]  eta: 0:03:58  lr: 0.000317  loss: 0.2382 (4.9916)  loss_classifier: 0.0226 (0.1777)  loss_box_reg: 0.0520 (0.1480)  loss_mask: 0.1551 (3.6788)  loss_objectness: 0.0033 (0.9029)  loss_rpn_box_reg: 0.0032 (0.0842)  time: 0.7224  data: 0.0768  max mem: 6911
# Epoch: [0]  [160/478]  eta: 0:03:50  lr: 0.000338  loss: 0.2382 (4.6967)  loss_classifier: 0.0226 (0.1679)  loss_box_reg: 0.0596 (0.1426)  loss_mask: 0.1551 (3.4597)  loss_objectness: 0.0027 (0.8474)  loss_rpn_box_reg: 0.0027 (0.0792)  time: 0.7242  data: 0.0769  max mem: 6911
# Epoch: [0]  [170/478]  eta: 0:03:43  lr: 0.000359  loss: 0.2262 (4.4356)  loss_classifier: 0.0191 (0.1592)  loss_box_reg: 0.0625 (0.1382)  loss_mask: 0.1407 (3.2656)  loss_objectness: 0.0026 (0.7980)  loss_rpn_box_reg: 0.0024 (0.0747)  time: 0.7255  data: 0.0770  max mem: 6911
# Epoch: [0]  [180/478]  eta: 0:03:36  lr: 0.000380  loss: 0.2361 (4.2040)  loss_classifier: 0.0191 (0.1514)  loss_box_reg: 0.0600 (0.1337)  loss_mask: 0.1422 (3.0940)  loss_objectness: 0.0022 (0.7541)  loss_rpn_box_reg: 0.0025 (0.0707)  time: 0.7270  data: 0.0766  max mem: 6911
# Epoch: [0]  [190/478]  eta: 0:03:29  lr: 0.000401  loss: 0.2101 (3.9955)  loss_classifier: 0.0168 (0.1444)  loss_box_reg: 0.0545 (0.1296)  loss_mask: 0.1438 (2.9396)  loss_objectness: 0.0022 (0.7147)  loss_rpn_box_reg: 0.0025 (0.0672)  time: 0.7256  data: 0.0766  max mem: 6911
# Epoch: [0]  [200/478]  eta: 0:03:21  lr: 0.000422  loss: 0.2091 (3.8069)  loss_classifier: 0.0177 (0.1383)  loss_box_reg: 0.0526 (0.1257)  loss_mask: 0.1339 (2.7997)  loss_objectness: 0.0016 (0.6792)  loss_rpn_box_reg: 0.0024 (0.0640)  time: 0.7252  data: 0.0765  max mem: 6911
# Epoch: [0]  [210/478]  eta: 0:03:14  lr: 0.000443  loss: 0.1943 (3.6352)  loss_classifier: 0.0202 (0.1327)  loss_box_reg: 0.0465 (0.1219)  loss_mask: 0.1193 (2.6725)  loss_objectness: 0.0013 (0.6471)  loss_rpn_box_reg: 0.0024 (0.0610)  time: 0.7251  data: 0.0761  max mem: 6911
# Epoch: [0]  [220/478]  eta: 0:03:07  lr: 0.000464  loss: 0.1764 (3.4787)  loss_classifier: 0.0170 (0.1274)  loss_box_reg: 0.0419 (0.1183)  loss_mask: 0.1097 (2.5566)  loss_objectness: 0.0007 (0.6180)  loss_rpn_box_reg: 0.0024 (0.0584)  time: 0.7245  data: 0.0758  max mem: 6911
# Epoch: [0]  [230/478]  eta: 0:03:00  lr: 0.000485  loss: 0.1729 (3.3358)  loss_classifier: 0.0147 (0.1225)  loss_box_reg: 0.0410 (0.1148)  loss_mask: 0.1058 (2.4512)  loss_objectness: 0.0011 (0.5913)  loss_rpn_box_reg: 0.0018 (0.0560)  time: 0.7241  data: 0.0761  max mem: 6911
# Epoch: [0]  [240/478]  eta: 0:02:52  lr: 0.000506  loss: 0.1644 (3.2041)  loss_classifier: 0.0115 (0.1179)  loss_box_reg: 0.0347 (0.1115)  loss_mask: 0.1092 (2.3540)  loss_objectness: 0.0016 (0.5669)  loss_rpn_box_reg: 0.0016 (0.0537)  time: 0.7246  data: 0.0767  max mem: 6911
# Epoch: [0]  [250/478]  eta: 0:02:45  lr: 0.000527  loss: 0.1527 (3.0830)  loss_classifier: 0.0131 (0.1138)  loss_box_reg: 0.0346 (0.1086)  loss_mask: 0.1031 (2.2645)  loss_objectness: 0.0015 (0.5444)  loss_rpn_box_reg: 0.0018 (0.0517)  time: 0.7238  data: 0.0757  max mem: 6911
# Epoch: [0]  [260/478]  eta: 0:02:38  lr: 0.000548  loss: 0.1701 (2.9719)  loss_classifier: 0.0149 (0.1101)  loss_box_reg: 0.0389 (0.1060)  loss_mask: 0.1075 (2.1824)  loss_objectness: 0.0012 (0.5236)  loss_rpn_box_reg: 0.0017 (0.0498)  time: 0.7250  data: 0.0761  max mem: 6911
# Epoch: [0]  [270/478]  eta: 0:02:31  lr: 0.000569  loss: 0.1661 (2.8682)  loss_classifier: 0.0162 (0.1066)  loss_box_reg: 0.0392 (0.1035)  loss_mask: 0.1061 (2.1057)  loss_objectness: 0.0007 (0.5043)  loss_rpn_box_reg: 0.0017 (0.0480)  time: 0.7282  data: 0.0774  max mem: 6911
# Epoch: [0]  [280/478]  eta: 0:02:23  lr: 0.000590  loss: 0.1480 (2.7714)  loss_classifier: 0.0143 (0.1033)  loss_box_reg: 0.0360 (0.1011)  loss_mask: 0.0986 (2.0342)  loss_objectness: 0.0006 (0.4864)  loss_rpn_box_reg: 0.0019 (0.0464)  time: 0.7272  data: 0.0780  max mem: 6911
# Epoch: [0]  [290/478]  eta: 0:02:16  lr: 0.000610  loss: 0.1474 (2.6812)  loss_classifier: 0.0132 (0.1002)  loss_box_reg: 0.0353 (0.0989)  loss_mask: 0.0933 (1.9675)  loss_objectness: 0.0005 (0.4697)  loss_rpn_box_reg: 0.0019 (0.0449)  time: 0.7259  data: 0.0777  max mem: 6911
# Epoch: [0]  [300/478]  eta: 0:02:09  lr: 0.000631  loss: 0.1484 (2.5972)  loss_classifier: 0.0134 (0.0973)  loss_box_reg: 0.0371 (0.0968)  loss_mask: 0.0930 (1.9055)  loss_objectness: 0.0004 (0.4541)  loss_rpn_box_reg: 0.0018 (0.0435)  time: 0.7255  data: 0.0771  max mem: 6911
# Epoch: [0]  [310/478]  eta: 0:02:01  lr: 0.000652  loss: 0.1484 (2.5188)  loss_classifier: 0.0126 (0.0946)  loss_box_reg: 0.0359 (0.0949)  loss_mask: 0.0969 (1.8476)  loss_objectness: 0.0007 (0.4396)  loss_rpn_box_reg: 0.0018 (0.0421)  time: 0.7230  data: 0.0764  max mem: 6911
# Epoch: [0]  [320/478]  eta: 0:01:54  lr: 0.000673  loss: 0.1441 (2.4447)  loss_classifier: 0.0126 (0.0920)  loss_box_reg: 0.0346 (0.0930)  loss_mask: 0.0934 (1.7929)  loss_objectness: 0.0006 (0.4259)  loss_rpn_box_reg: 0.0017 (0.0409)  time: 0.7222  data: 0.0756  max mem: 6911
# Epoch: [0]  [330/478]  eta: 0:01:47  lr: 0.000694  loss: 0.1419 (2.3753)  loss_classifier: 0.0131 (0.0897)  loss_box_reg: 0.0358 (0.0913)  loss_mask: 0.0917 (1.7416)  loss_objectness: 0.0003 (0.4130)  loss_rpn_box_reg: 0.0014 (0.0397)  time: 0.7234  data: 0.0757  max mem: 6911
# Epoch: [0]  [340/478]  eta: 0:01:40  lr: 0.000715  loss: 0.1446 (2.3100)  loss_classifier: 0.0127 (0.0874)  loss_box_reg: 0.0382 (0.0898)  loss_mask: 0.0884 (1.6932)  loss_objectness: 0.0006 (0.4010)  loss_rpn_box_reg: 0.0015 (0.0386)  time: 0.7280  data: 0.0765  max mem: 6911
# Epoch: [0]  [350/478]  eta: 0:01:32  lr: 0.000736  loss: 0.1433 (2.2482)  loss_classifier: 0.0125 (0.0853)  loss_box_reg: 0.0382 (0.0883)  loss_mask: 0.0879 (1.6475)  loss_objectness: 0.0007 (0.3896)  loss_rpn_box_reg: 0.0015 (0.0376)  time: 0.7300  data: 0.0775  max mem: 6911
# Epoch: [0]  [360/478]  eta: 0:01:25  lr: 0.000757  loss: 0.1396 (2.1898)  loss_classifier: 0.0125 (0.0832)  loss_box_reg: 0.0368 (0.0869)  loss_mask: 0.0869 (1.6043)  loss_objectness: 0.0009 (0.3788)  loss_rpn_box_reg: 0.0017 (0.0366)  time: 0.7269  data: 0.0767  max mem: 6911
# Epoch: [0]  [370/478]  eta: 0:01:18  lr: 0.000778  loss: 0.1395 (2.1345)  loss_classifier: 0.0125 (0.0814)  loss_box_reg: 0.0343 (0.0854)  loss_mask: 0.0871 (1.5634)  loss_objectness: 0.0009 (0.3686)  loss_rpn_box_reg: 0.0021 (0.0357)  time: 0.7264  data: 0.0764  max mem: 6911
# Epoch: [0]  [380/478]  eta: 0:01:11  lr: 0.000799  loss: 0.1372 (2.0821)  loss_classifier: 0.0133 (0.0796)  loss_box_reg: 0.0336 (0.0841)  loss_mask: 0.0861 (1.5247)  loss_objectness: 0.0004 (0.3590)  loss_rpn_box_reg: 0.0020 (0.0348)  time: 0.7277  data: 0.0764  max mem: 6911
# Epoch: [0]  [390/478]  eta: 0:01:03  lr: 0.000820  loss: 0.1362 (2.0325)  loss_classifier: 0.0133 (0.0779)  loss_box_reg: 0.0346 (0.0828)  loss_mask: 0.0866 (1.4880)  loss_objectness: 0.0004 (0.3498)  loss_rpn_box_reg: 0.0019 (0.0340)  time: 0.7290  data: 0.0750  max mem: 6911
# Epoch: [0]  [400/478]  eta: 0:00:56  lr: 0.000841  loss: 0.1387 (1.9853)  loss_classifier: 0.0129 (0.0763)  loss_box_reg: 0.0357 (0.0817)  loss_mask: 0.0883 (1.4531)  loss_objectness: 0.0004 (0.3411)  loss_rpn_box_reg: 0.0019 (0.0332)  time: 0.7292  data: 0.0747  max mem: 6911
# Epoch: [0]  [410/478]  eta: 0:00:49  lr: 0.000862  loss: 0.1387 (1.9405)  loss_classifier: 0.0130 (0.0747)  loss_box_reg: 0.0361 (0.0805)  loss_mask: 0.0866 (1.4200)  loss_objectness: 0.0004 (0.3328)  loss_rpn_box_reg: 0.0013 (0.0324)  time: 0.7290  data: 0.0762  max mem: 6911
# Epoch: [0]  [420/478]  eta: 0:00:42  lr: 0.000883  loss: 0.1444 (1.8981)  loss_classifier: 0.0129 (0.0733)  loss_box_reg: 0.0370 (0.0796)  loss_mask: 0.0866 (1.3886)  loss_objectness: 0.0004 (0.3249)  loss_rpn_box_reg: 0.0014 (0.0317)  time: 0.7327  data: 0.0787  max mem: 6911
# Epoch: [0]  [430/478]  eta: 0:00:34  lr: 0.000904  loss: 0.1474 (1.8576)  loss_classifier: 0.0126 (0.0719)  loss_box_reg: 0.0381 (0.0787)  loss_mask: 0.0942 (1.3586)  loss_objectness: 0.0001 (0.3174)  loss_rpn_box_reg: 0.0015 (0.0310)  time: 0.7344  data: 0.0793  max mem: 6911
# Epoch: [0]  [440/478]  eta: 0:00:27  lr: 0.000925  loss: 0.1474 (1.8189)  loss_classifier: 0.0132 (0.0706)  loss_box_reg: 0.0428 (0.0779)  loss_mask: 0.0934 (1.3298)  loss_objectness: 0.0004 (0.3103)  loss_rpn_box_reg: 0.0015 (0.0303)  time: 0.7352  data: 0.0799  max mem: 6911
# Epoch: [0]  [450/478]  eta: 0:00:20  lr: 0.000946  loss: 0.1436 (1.7818)  loss_classifier: 0.0161 (0.0694)  loss_box_reg: 0.0440 (0.0771)  loss_mask: 0.0819 (1.3022)  loss_objectness: 0.0004 (0.3034)  loss_rpn_box_reg: 0.0014 (0.0297)  time: 0.7408  data: 0.0818  max mem: 6911
# Epoch: [0]  [460/478]  eta: 0:00:13  lr: 0.000966  loss: 0.1408 (1.7462)  loss_classifier: 0.0158 (0.0683)  loss_box_reg: 0.0425 (0.0763)  loss_mask: 0.0801 (1.2757)  loss_objectness: 0.0002 (0.2968)  loss_rpn_box_reg: 0.0018 (0.0291)  time: 0.7412  data: 0.0814  max mem: 6911
# Epoch: [0]  [470/478]  eta: 0:00:05  lr: 0.000987  loss: 0.1350 (1.7120)  loss_classifier: 0.0146 (0.0671)  loss_box_reg: 0.0389 (0.0755)  loss_mask: 0.0797 (1.2503)  loss_objectness: 0.0006 (0.2906)  loss_rpn_box_reg: 0.0017 (0.0285)  time: 0.7383  data: 0.0806  max mem: 6911
# Epoch: [0]  [477/478]  eta: 0:00:00  lr: 0.001000  loss: 0.1316 (1.6889)  loss_classifier: 0.0137 (0.0663)  loss_box_reg: 0.0377 (0.0749)  loss_mask: 0.0800 (1.2332)  loss_objectness: 0.0006 (0.2863)  loss_rpn_box_reg: 0.0017 (0.0281)  time: 0.7106  data: 0.0767  max mem: 6911
# Epoch: [0] Total time: 0:05:47 (0.7268 s / it)
# Epoch: [1]  [  0/478]  eta: 0:05:29  lr: 0.001000  loss: 0.1720 (0.1720)  loss_classifier: 0.0143 (0.0143)  loss_box_reg: 0.0605 (0.0605)  loss_mask: 0.0950 (0.0950)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0021 (0.0021)  time: 0.6885  data: 0.0350  max mem: 6911
# Epoch: [1]  [ 10/478]  eta: 0:05:23  lr: 0.001000  loss: 0.1310 (0.1379)  loss_classifier: 0.0122 (0.0132)  loss_box_reg: 0.0374 (0.0386)  loss_mask: 0.0806 (0.0833)  loss_objectness: 0.0005 (0.0008)  loss_rpn_box_reg: 0.0017 (0.0020)  time: 0.6916  data: 0.0380  max mem: 6911
# Epoch: [1]  [ 20/478]  eta: 0:05:18  lr: 0.001000  loss: 0.1409 (0.1442)  loss_classifier: 0.0137 (0.0140)  loss_box_reg: 0.0421 (0.0410)  loss_mask: 0.0816 (0.0863)  loss_objectness: 0.0007 (0.0010)  loss_rpn_box_reg: 0.0017 (0.0020)  time: 0.6949  data: 0.0370  max mem: 6911
# Epoch: [1]  [ 30/478]  eta: 0:05:11  lr: 0.001000  loss: 0.1399 (0.1383)  loss_classifier: 0.0135 (0.0137)  loss_box_reg: 0.0383 (0.0378)  loss_mask: 0.0797 (0.0837)  loss_objectness: 0.0008 (0.0011)  loss_rpn_box_reg: 0.0020 (0.0021)  time: 0.6962  data: 0.0357  max mem: 6911
# Epoch: [1]  [ 40/478]  eta: 0:05:04  lr: 0.001000  loss: 0.1179 (0.1329)  loss_classifier: 0.0104 (0.0126)  loss_box_reg: 0.0307 (0.0360)  loss_mask: 0.0749 (0.0814)  loss_objectness: 0.0003 (0.0009)  loss_rpn_box_reg: 0.0017 (0.0019)  time: 0.6942  data: 0.0355  max mem: 6911
# Epoch: [1]  [ 50/478]  eta: 0:04:57  lr: 0.001000  loss: 0.1181 (0.1305)  loss_classifier: 0.0096 (0.0124)  loss_box_reg: 0.0307 (0.0348)  loss_mask: 0.0756 (0.0807)  loss_objectness: 0.0000 (0.0009)  loss_rpn_box_reg: 0.0012 (0.0019)  time: 0.6952  data: 0.0358  max mem: 6911
# Epoch: [1]  [ 60/478]  eta: 0:04:50  lr: 0.001000  loss: 0.1171 (0.1280)  loss_classifier: 0.0113 (0.0121)  loss_box_reg: 0.0278 (0.0337)  loss_mask: 0.0756 (0.0794)  loss_objectness: 0.0001 (0.0008)  loss_rpn_box_reg: 0.0015 (0.0018)  time: 0.6959  data: 0.0361  max mem: 6911
# Epoch: [1]  [ 70/478]  eta: 0:04:43  lr: 0.001000  loss: 0.1162 (0.1302)  loss_classifier: 0.0106 (0.0121)  loss_box_reg: 0.0269 (0.0329)  loss_mask: 0.0744 (0.0813)  loss_objectness: 0.0004 (0.0020)  loss_rpn_box_reg: 0.0015 (0.0019)  time: 0.6933  data: 0.0358  max mem: 6911
# Epoch: [1]  [ 80/478]  eta: 0:04:36  lr: 0.001000  loss: 0.1891 (0.1425)  loss_classifier: 0.0127 (0.0126)  loss_box_reg: 0.0416 (0.0363)  loss_mask: 0.1187 (0.0893)  loss_objectness: 0.0020 (0.0022)  loss_rpn_box_reg: 0.0019 (0.0020)  time: 0.6901  data: 0.0358  max mem: 6911
# Epoch: [1]  [ 90/478]  eta: 0:04:28  lr: 0.001000  loss: 0.2220 (0.1496)  loss_classifier: 0.0142 (0.0129)  loss_box_reg: 0.0489 (0.0373)  loss_mask: 0.1312 (0.0953)  loss_objectness: 0.0016 (0.0021)  loss_rpn_box_reg: 0.0022 (0.0020)  time: 0.6883  data: 0.0367  max mem: 6911
# Epoch: [1]  [100/478]  eta: 0:04:21  lr: 0.001000  loss: 0.1952 (0.1559)  loss_classifier: 0.0125 (0.0130)  loss_box_reg: 0.0434 (0.0376)  loss_mask: 0.1301 (0.1011)  loss_objectness: 0.0013 (0.0022)  loss_rpn_box_reg: 0.0021 (0.0020)  time: 0.6870  data: 0.0371  max mem: 6911
# Epoch: [1]  [110/478]  eta: 0:04:14  lr: 0.001000  loss: 0.1677 (0.1551)  loss_classifier: 0.0120 (0.0128)  loss_box_reg: 0.0360 (0.0373)  loss_mask: 0.1091 (0.1007)  loss_objectness: 0.0014 (0.0021)  loss_rpn_box_reg: 0.0018 (0.0020)  time: 0.6858  data: 0.0370  max mem: 6911
# Epoch: [1]  [120/478]  eta: 0:04:07  lr: 0.001000  loss: 0.1251 (0.1524)  loss_classifier: 0.0100 (0.0125)  loss_box_reg: 0.0282 (0.0364)  loss_mask: 0.0883 (0.0994)  loss_objectness: 0.0006 (0.0020)  loss_rpn_box_reg: 0.0017 (0.0020)  time: 0.6849  data: 0.0371  max mem: 6911
# Epoch: [1]  [130/478]  eta: 0:04:00  lr: 0.001000  loss: 0.1169 (0.1497)  loss_classifier: 0.0078 (0.0122)  loss_box_reg: 0.0244 (0.0355)  loss_mask: 0.0802 (0.0980)  loss_objectness: 0.0001 (0.0019)  loss_rpn_box_reg: 0.0017 (0.0021)  time: 0.6864  data: 0.0371  max mem: 6911
# Epoch: [1]  [140/478]  eta: 0:03:53  lr: 0.001000  loss: 0.1082 (0.1468)  loss_classifier: 0.0077 (0.0118)  loss_box_reg: 0.0219 (0.0344)  loss_mask: 0.0783 (0.0967)  loss_objectness: 0.0003 (0.0018)  loss_rpn_box_reg: 0.0015 (0.0020)  time: 0.6872  data: 0.0370  max mem: 6911
# Epoch: [1]  [150/478]  eta: 0:03:46  lr: 0.001000  loss: 0.1046 (0.1440)  loss_classifier: 0.0078 (0.0116)  loss_box_reg: 0.0192 (0.0334)  loss_mask: 0.0764 (0.0953)  loss_objectness: 0.0002 (0.0018)  loss_rpn_box_reg: 0.0013 (0.0020)  time: 0.6852  data: 0.0369  max mem: 6911
# Epoch: [1]  [160/478]  eta: 0:03:39  lr: 0.001000  loss: 0.1107 (0.1435)  loss_classifier: 0.0079 (0.0114)  loss_box_reg: 0.0209 (0.0331)  loss_mask: 0.0798 (0.0953)  loss_objectness: 0.0005 (0.0017)  loss_rpn_box_reg: 0.0014 (0.0020)  time: 0.6850  data: 0.0370  max mem: 6911
# Epoch: [1]  [170/478]  eta: 0:03:32  lr: 0.001000  loss: 0.1236 (0.1426)  loss_classifier: 0.0083 (0.0112)  loss_box_reg: 0.0264 (0.0328)  loss_mask: 0.0859 (0.0950)  loss_objectness: 0.0004 (0.0016)  loss_rpn_box_reg: 0.0019 (0.0020)  time: 0.6849  data: 0.0368  max mem: 6911
# Epoch: [1]  [180/478]  eta: 0:03:25  lr: 0.001000  loss: 0.1153 (0.1408)  loss_classifier: 0.0080 (0.0110)  loss_box_reg: 0.0233 (0.0323)  loss_mask: 0.0800 (0.0939)  loss_objectness: 0.0001 (0.0016)  loss_rpn_box_reg: 0.0016 (0.0020)  time: 0.6846  data: 0.0368  max mem: 6911
# Epoch: [1]  [190/478]  eta: 0:03:18  lr: 0.001000  loss: 0.1056 (0.1390)  loss_classifier: 0.0070 (0.0108)  loss_box_reg: 0.0213 (0.0317)  loss_mask: 0.0765 (0.0931)  loss_objectness: 0.0000 (0.0015)  loss_rpn_box_reg: 0.0013 (0.0020)  time: 0.6855  data: 0.0368  max mem: 6911
# Epoch: [1]  [200/478]  eta: 0:03:11  lr: 0.001000  loss: 0.1033 (0.1372)  loss_classifier: 0.0064 (0.0106)  loss_box_reg: 0.0197 (0.0310)  loss_mask: 0.0756 (0.0922)  loss_objectness: 0.0001 (0.0014)  loss_rpn_box_reg: 0.0013 (0.0020)  time: 0.6868  data: 0.0367  max mem: 6911
# Epoch: [1]  [210/478]  eta: 0:03:04  lr: 0.001000  loss: 0.0974 (0.1355)  loss_classifier: 0.0065 (0.0104)  loss_box_reg: 0.0184 (0.0305)  loss_mask: 0.0723 (0.0913)  loss_objectness: 0.0001 (0.0014)  loss_rpn_box_reg: 0.0013 (0.0020)  time: 0.6888  data: 0.0369  max mem: 6911
# Epoch: [1]  [220/478]  eta: 0:02:57  lr: 0.001000  loss: 0.0997 (0.1340)  loss_classifier: 0.0064 (0.0102)  loss_box_reg: 0.0196 (0.0300)  loss_mask: 0.0718 (0.0905)  loss_objectness: 0.0001 (0.0013)  loss_rpn_box_reg: 0.0012 (0.0020)  time: 0.6884  data: 0.0371  max mem: 6911
# Epoch: [1]  [230/478]  eta: 0:02:50  lr: 0.001000  loss: 0.1004 (0.1327)  loss_classifier: 0.0072 (0.0101)  loss_box_reg: 0.0187 (0.0295)  loss_mask: 0.0737 (0.0898)  loss_objectness: 0.0001 (0.0013)  loss_rpn_box_reg: 0.0015 (0.0019)  time: 0.6875  data: 0.0371  max mem: 6911
# Epoch: [1]  [240/478]  eta: 0:02:43  lr: 0.001000  loss: 0.1025 (0.1315)  loss_classifier: 0.0074 (0.0100)  loss_box_reg: 0.0193 (0.0291)  loss_mask: 0.0740 (0.0892)  loss_objectness: 0.0000 (0.0012)  loss_rpn_box_reg: 0.0016 (0.0020)  time: 0.6863  data: 0.0372  max mem: 6911
# Epoch: [1]  [250/478]  eta: 0:02:37  lr: 0.001000  loss: 0.1002 (0.1302)  loss_classifier: 0.0066 (0.0099)  loss_box_reg: 0.0193 (0.0287)  loss_mask: 0.0723 (0.0885)  loss_objectness: 0.0000 (0.0012)  loss_rpn_box_reg: 0.0013 (0.0019)  time: 0.6851  data: 0.0368  max mem: 6911
# Epoch: [1]  [260/478]  eta: 0:02:30  lr: 0.001000  loss: 0.0984 (0.1291)  loss_classifier: 0.0072 (0.0098)  loss_box_reg: 0.0183 (0.0283)  loss_mask: 0.0708 (0.0879)  loss_objectness: 0.0000 (0.0012)  loss_rpn_box_reg: 0.0013 (0.0019)  time: 0.6851  data: 0.0365  max mem: 6911
# Epoch: [1]  [270/478]  eta: 0:02:23  lr: 0.001000  loss: 0.1013 (0.1284)  loss_classifier: 0.0073 (0.0097)  loss_box_reg: 0.0183 (0.0281)  loss_mask: 0.0742 (0.0876)  loss_objectness: 0.0001 (0.0011)  loss_rpn_box_reg: 0.0014 (0.0019)  time: 0.6853  data: 0.0369  max mem: 6911
# Epoch: [1]  [280/478]  eta: 0:02:16  lr: 0.001000  loss: 0.1103 (0.1278)  loss_classifier: 0.0077 (0.0097)  loss_box_reg: 0.0204 (0.0278)  loss_mask: 0.0789 (0.0873)  loss_objectness: 0.0001 (0.0011)  loss_rpn_box_reg: 0.0016 (0.0019)  time: 0.6863  data: 0.0371  max mem: 6911
# Epoch: [1]  [290/478]  eta: 0:02:09  lr: 0.001000  loss: 0.1058 (0.1271)  loss_classifier: 0.0076 (0.0096)  loss_box_reg: 0.0212 (0.0276)  loss_mask: 0.0772 (0.0870)  loss_objectness: 0.0002 (0.0011)  loss_rpn_box_reg: 0.0015 (0.0019)  time: 0.6856  data: 0.0372  max mem: 6911
# Epoch: [1]  [300/478]  eta: 0:02:02  lr: 0.001000  loss: 0.1021 (0.1262)  loss_classifier: 0.0060 (0.0095)  loss_box_reg: 0.0190 (0.0273)  loss_mask: 0.0747 (0.0865)  loss_objectness: 0.0000 (0.0010)  loss_rpn_box_reg: 0.0012 (0.0019)  time: 0.6854  data: 0.0372  max mem: 6911
# Epoch: [1]  [310/478]  eta: 0:01:55  lr: 0.001000  loss: 0.0980 (0.1255)  loss_classifier: 0.0072 (0.0094)  loss_box_reg: 0.0190 (0.0271)  loss_mask: 0.0729 (0.0862)  loss_objectness: 0.0000 (0.0010)  loss_rpn_box_reg: 0.0012 (0.0019)  time: 0.6847  data: 0.0370  max mem: 6911
# Epoch: [1]  [320/478]  eta: 0:01:48  lr: 0.001000  loss: 0.1014 (0.1250)  loss_classifier: 0.0076 (0.0094)  loss_box_reg: 0.0205 (0.0269)  loss_mask: 0.0733 (0.0859)  loss_objectness: 0.0000 (0.0010)  loss_rpn_box_reg: 0.0016 (0.0019)  time: 0.6847  data: 0.0368  max mem: 6911
# Epoch: [1]  [330/478]  eta: 0:01:41  lr: 0.001000  loss: 0.1013 (0.1242)  loss_classifier: 0.0072 (0.0093)  loss_box_reg: 0.0197 (0.0266)  loss_mask: 0.0720 (0.0855)  loss_objectness: 0.0000 (0.0009)  loss_rpn_box_reg: 0.0012 (0.0019)  time: 0.6862  data: 0.0368  max mem: 6911
# Epoch: [1]  [340/478]  eta: 0:01:34  lr: 0.001000  loss: 0.0979 (0.1234)  loss_classifier: 0.0060 (0.0092)  loss_box_reg: 0.0185 (0.0264)  loss_mask: 0.0720 (0.0851)  loss_objectness: 0.0000 (0.0009)  loss_rpn_box_reg: 0.0009 (0.0018)  time: 0.6848  data: 0.0369  max mem: 6911
# Epoch: [1]  [350/478]  eta: 0:01:28  lr: 0.001000  loss: 0.0979 (0.1227)  loss_classifier: 0.0059 (0.0091)  loss_box_reg: 0.0179 (0.0261)  loss_mask: 0.0708 (0.0847)  loss_objectness: 0.0000 (0.0009)  loss_rpn_box_reg: 0.0009 (0.0018)  time: 0.6832  data: 0.0368  max mem: 6911
# Epoch: [1]  [360/478]  eta: 0:01:21  lr: 0.001000  loss: 0.0936 (0.1219)  loss_classifier: 0.0064 (0.0091)  loss_box_reg: 0.0155 (0.0258)  loss_mask: 0.0706 (0.0843)  loss_objectness: 0.0000 (0.0009)  loss_rpn_box_reg: 0.0011 (0.0018)  time: 0.6832  data: 0.0367  max mem: 6911
# Epoch: [1]  [370/478]  eta: 0:01:14  lr: 0.001000  loss: 0.1003 (0.1215)  loss_classifier: 0.0066 (0.0090)  loss_box_reg: 0.0163 (0.0256)  loss_mask: 0.0737 (0.0842)  loss_objectness: 0.0000 (0.0009)  loss_rpn_box_reg: 0.0010 (0.0018)  time: 0.6854  data: 0.0367  max mem: 6911
# Epoch: [1]  [380/478]  eta: 0:01:07  lr: 0.001000  loss: 0.0977 (0.1208)  loss_classifier: 0.0064 (0.0089)  loss_box_reg: 0.0170 (0.0254)  loss_mask: 0.0728 (0.0839)  loss_objectness: 0.0000 (0.0008)  loss_rpn_box_reg: 0.0007 (0.0018)  time: 0.6876  data: 0.0368  max mem: 6911
# Epoch: [1]  [390/478]  eta: 0:01:00  lr: 0.001000  loss: 0.0936 (0.1201)  loss_classifier: 0.0063 (0.0089)  loss_box_reg: 0.0164 (0.0252)  loss_mask: 0.0692 (0.0835)  loss_objectness: 0.0000 (0.0008)  loss_rpn_box_reg: 0.0006 (0.0018)  time: 0.6892  data: 0.0369  max mem: 6911
# Epoch: [1]  [400/478]  eta: 0:00:53  lr: 0.001000  loss: 0.0962 (0.1196)  loss_classifier: 0.0061 (0.0088)  loss_box_reg: 0.0154 (0.0250)  loss_mask: 0.0703 (0.0833)  loss_objectness: 0.0000 (0.0008)  loss_rpn_box_reg: 0.0010 (0.0017)  time: 0.6899  data: 0.0367  max mem: 6911
# Epoch: [1]  [410/478]  eta: 0:00:46  lr: 0.001000  loss: 0.1011 (0.1192)  loss_classifier: 0.0057 (0.0087)  loss_box_reg: 0.0187 (0.0249)  loss_mask: 0.0754 (0.0831)  loss_objectness: 0.0000 (0.0008)  loss_rpn_box_reg: 0.0011 (0.0017)  time: 0.6874  data: 0.0367  max mem: 6911
# Epoch: [1]  [420/478]  eta: 0:00:39  lr: 0.001000  loss: 0.0963 (0.1187)  loss_classifier: 0.0059 (0.0087)  loss_box_reg: 0.0202 (0.0247)  loss_mask: 0.0727 (0.0828)  loss_objectness: 0.0000 (0.0008)  loss_rpn_box_reg: 0.0009 (0.0017)  time: 0.6854  data: 0.0369  max mem: 6911
# Epoch: [1]  [430/478]  eta: 0:00:32  lr: 0.001000  loss: 0.1004 (0.1184)  loss_classifier: 0.0061 (0.0086)  loss_box_reg: 0.0185 (0.0247)  loss_mask: 0.0728 (0.0826)  loss_objectness: 0.0000 (0.0008)  loss_rpn_box_reg: 0.0009 (0.0017)  time: 0.6859  data: 0.0369  max mem: 6911
# Epoch: [1]  [440/478]  eta: 0:00:26  lr: 0.001000  loss: 0.0989 (0.1179)  loss_classifier: 0.0061 (0.0086)  loss_box_reg: 0.0178 (0.0245)  loss_mask: 0.0728 (0.0824)  loss_objectness: 0.0000 (0.0007)  loss_rpn_box_reg: 0.0008 (0.0017)  time: 0.6857  data: 0.0369  max mem: 6911
# Epoch: [1]  [450/478]  eta: 0:00:19  lr: 0.001000  loss: 0.0965 (0.1174)  loss_classifier: 0.0051 (0.0085)  loss_box_reg: 0.0178 (0.0244)  loss_mask: 0.0697 (0.0821)  loss_objectness: 0.0000 (0.0007)  loss_rpn_box_reg: 0.0010 (0.0017)  time: 0.6848  data: 0.0368  max mem: 6911
# Epoch: [1]  [460/478]  eta: 0:00:12  lr: 0.001000  loss: 0.0950 (0.1169)  loss_classifier: 0.0057 (0.0085)  loss_box_reg: 0.0171 (0.0242)  loss_mask: 0.0698 (0.0819)  loss_objectness: 0.0000 (0.0007)  loss_rpn_box_reg: 0.0012 (0.0017)  time: 0.6852  data: 0.0369  max mem: 6911
# Epoch: [1]  [470/478]  eta: 0:00:05  lr: 0.001000  loss: 0.0972 (0.1169)  loss_classifier: 0.0062 (0.0084)  loss_box_reg: 0.0178 (0.0242)  loss_mask: 0.0706 (0.0820)  loss_objectness: 0.0000 (0.0007)  loss_rpn_box_reg: 0.0008 (0.0016)  time: 0.6850  data: 0.0372  max mem: 6911
# Epoch: [1]  [477/478]  eta: 0:00:00  lr: 0.001000  loss: 0.0962 (0.1167)  loss_classifier: 0.0062 (0.0084)  loss_box_reg: 0.0191 (0.0241)  loss_mask: 0.0719 (0.0819)  loss_objectness: 0.0000 (0.0007)  loss_rpn_box_reg: 0.0007 (0.0016)  time: 0.6552  data: 0.0355  max mem: 6911
# Epoch: [1] Total time: 0:05:27 (0.6861 s / it)
# Epoch: [2]  [  0/478]  eta: 0:05:31  lr: 0.001000  loss: 0.1055 (0.1055)  loss_classifier: 0.0073 (0.0073)  loss_box_reg: 0.0220 (0.0220)  loss_mask: 0.0745 (0.0745)  loss_objectness: 0.0010 (0.0010)  loss_rpn_box_reg: 0.0007 (0.0007)  time: 0.6936  data: 0.0340  max mem: 6911
# Epoch: [2]  [ 10/478]  eta: 0:05:21  lr: 0.001000  loss: 0.0988 (0.0988)  loss_classifier: 0.0065 (0.0065)  loss_box_reg: 0.0180 (0.0193)  loss_mask: 0.0705 (0.0718)  loss_objectness: 0.0000 (0.0001)  loss_rpn_box_reg: 0.0008 (0.0011)  time: 0.6868  data: 0.0371  max mem: 6911
# Epoch: [2]  [ 20/478]  eta: 0:05:14  lr: 0.001000  loss: 0.0988 (0.1033)  loss_classifier: 0.0065 (0.0071)  loss_box_reg: 0.0195 (0.0209)  loss_mask: 0.0705 (0.0739)  loss_objectness: 0.0000 (0.0001)  loss_rpn_box_reg: 0.0010 (0.0012)  time: 0.6862  data: 0.0371  max mem: 6911
# Epoch: [2]  [ 30/478]  eta: 0:05:06  lr: 0.001000  loss: 0.0992 (0.1031)  loss_classifier: 0.0068 (0.0068)  loss_box_reg: 0.0207 (0.0207)  loss_mask: 0.0716 (0.0744)  loss_objectness: 0.0000 (0.0001)  loss_rpn_box_reg: 0.0010 (0.0011)  time: 0.6843  data: 0.0366  max mem: 6911
# Epoch: [2]  [ 40/478]  eta: 0:04:59  lr: 0.001000  loss: 0.0959 (0.1013)  loss_classifier: 0.0063 (0.0066)  loss_box_reg: 0.0190 (0.0203)  loss_mask: 0.0699 (0.0733)  loss_objectness: 0.0000 (0.0001)  loss_rpn_box_reg: 0.0008 (0.0011)  time: 0.6830  data: 0.0367  max mem: 6911
# Epoch: [2]  [ 50/478]  eta: 0:04:52  lr: 0.001000  loss: 0.0909 (0.0991)  loss_classifier: 0.0063 (0.0065)  loss_box_reg: 0.0160 (0.0195)  loss_mask: 0.0667 (0.0721)  loss_objectness: 0.0000 (0.0001)  loss_rpn_box_reg: 0.0008 (0.0010)  time: 0.6827  data: 0.0369  max mem: 6911
# Epoch: [2]  [ 60/478]  eta: 0:04:45  lr: 0.001000  loss: 0.0907 (0.0983)  loss_classifier: 0.0063 (0.0064)  loss_box_reg: 0.0154 (0.0188)  loss_mask: 0.0678 (0.0721)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0007 (0.0010)  time: 0.6827  data: 0.0367  max mem: 6911
# Epoch: [2]  [ 70/478]  eta: 0:04:39  lr: 0.001000  loss: 0.0885 (0.0969)  loss_classifier: 0.0056 (0.0062)  loss_box_reg: 0.0143 (0.0181)  loss_mask: 0.0681 (0.0715)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0007 (0.0010)  time: 0.6846  data: 0.0368  max mem: 6911
# Epoch: [2]  [ 80/478]  eta: 0:04:32  lr: 0.001000  loss: 0.0857 (0.0960)  loss_classifier: 0.0046 (0.0061)  loss_box_reg: 0.0132 (0.0176)  loss_mask: 0.0678 (0.0713)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0008 (0.0010)  time: 0.6865  data: 0.0368  max mem: 6911
# Epoch: [2]  [ 90/478]  eta: 0:04:25  lr: 0.001000  loss: 0.0863 (0.0951)  loss_classifier: 0.0049 (0.0060)  loss_box_reg: 0.0132 (0.0172)  loss_mask: 0.0680 (0.0709)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0009 (0.0010)  time: 0.6882  data: 0.0366  max mem: 6911
# Epoch: [2]  [100/478]  eta: 0:04:19  lr: 0.001000  loss: 0.0899 (0.0955)  loss_classifier: 0.0054 (0.0060)  loss_box_reg: 0.0139 (0.0170)  loss_mask: 0.0689 (0.0715)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0009 (0.0010)  time: 0.6885  data: 0.0367  max mem: 6911
# Epoch: [2]  [110/478]  eta: 0:04:12  lr: 0.001000  loss: 0.0938 (0.0958)  loss_classifier: 0.0055 (0.0060)  loss_box_reg: 0.0165 (0.0173)  loss_mask: 0.0706 (0.0715)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0009 (0.0010)  time: 0.6881  data: 0.0367  max mem: 6911
# Epoch: [2]  [120/478]  eta: 0:04:05  lr: 0.001000  loss: 0.0971 (0.0962)  loss_classifier: 0.0058 (0.0060)  loss_box_reg: 0.0167 (0.0173)  loss_mask: 0.0723 (0.0719)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0009 (0.0010)  time: 0.6850  data: 0.0366  max mem: 6911
# Epoch: [2]  [130/478]  eta: 0:03:58  lr: 0.001000  loss: 0.0972 (0.0966)  loss_classifier: 0.0063 (0.0061)  loss_box_reg: 0.0162 (0.0174)  loss_mask: 0.0734 (0.0721)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0010 (0.0010)  time: 0.6826  data: 0.0365  max mem: 6911
# Epoch: [2]  [140/478]  eta: 0:03:51  lr: 0.001000  loss: 0.0980 (0.0968)  loss_classifier: 0.0063 (0.0061)  loss_box_reg: 0.0189 (0.0175)  loss_mask: 0.0708 (0.0722)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0008 (0.0010)  time: 0.6839  data: 0.0367  max mem: 6911
# Epoch: [2]  [150/478]  eta: 0:03:44  lr: 0.001000  loss: 0.0941 (0.0968)  loss_classifier: 0.0060 (0.0061)  loss_box_reg: 0.0181 (0.0174)  loss_mask: 0.0688 (0.0723)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0008 (0.0010)  time: 0.6836  data: 0.0369  max mem: 6911
# Epoch: [2]  [160/478]  eta: 0:03:37  lr: 0.001000  loss: 0.0900 (0.0966)  loss_classifier: 0.0056 (0.0060)  loss_box_reg: 0.0149 (0.0173)  loss_mask: 0.0681 (0.0723)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0008 (0.0010)  time: 0.6844  data: 0.0370  max mem: 6911
# Epoch: [2]  [170/478]  eta: 0:03:31  lr: 0.001000  loss: 0.0897 (0.0963)  loss_classifier: 0.0056 (0.0060)  loss_box_reg: 0.0139 (0.0171)  loss_mask: 0.0690 (0.0721)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0010 (0.0010)  time: 0.6856  data: 0.0371  max mem: 6911
# Epoch: [2]  [180/478]  eta: 0:03:24  lr: 0.001000  loss: 0.0895 (0.0960)  loss_classifier: 0.0057 (0.0060)  loss_box_reg: 0.0137 (0.0170)  loss_mask: 0.0693 (0.0720)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0009 (0.0010)  time: 0.6873  data: 0.0371  max mem: 6911
# Epoch: [2]  [190/478]  eta: 0:03:17  lr: 0.001000  loss: 0.0866 (0.0955)  loss_classifier: 0.0053 (0.0060)  loss_box_reg: 0.0123 (0.0168)  loss_mask: 0.0678 (0.0717)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0008 (0.0010)  time: 0.6880  data: 0.0372  max mem: 6911
# Epoch: [2]  [200/478]  eta: 0:03:10  lr: 0.001000  loss: 0.0841 (0.0949)  loss_classifier: 0.0049 (0.0059)  loss_box_reg: 0.0113 (0.0166)  loss_mask: 0.0655 (0.0714)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0008 (0.0010)  time: 0.6863  data: 0.0371  max mem: 6911
# Epoch: [2]  [210/478]  eta: 0:03:03  lr: 0.001000  loss: 0.0851 (0.0948)  loss_classifier: 0.0058 (0.0059)  loss_box_reg: 0.0121 (0.0165)  loss_mask: 0.0657 (0.0713)  loss_objectness: 0.0000 (0.0001)  loss_rpn_box_reg: 0.0009 (0.0010)  time: 0.6849  data: 0.0368  max mem: 6911
# Epoch: [2]  [220/478]  eta: 0:02:56  lr: 0.001000  loss: 0.0903 (0.0946)  loss_classifier: 0.0058 (0.0059)  loss_box_reg: 0.0161 (0.0165)  loss_mask: 0.0664 (0.0711)  loss_objectness: 0.0000 (0.0001)  loss_rpn_box_reg: 0.0009 (0.0010)  time: 0.6842  data: 0.0368  max mem: 6911
# Epoch: [2]  [230/478]  eta: 0:02:49  lr: 0.001000  loss: 0.0903 (0.0944)  loss_classifier: 0.0062 (0.0060)  loss_box_reg: 0.0167 (0.0165)  loss_mask: 0.0662 (0.0709)  loss_objectness: 0.0000 (0.0001)  loss_rpn_box_reg: 0.0008 (0.0010)  time: 0.6846  data: 0.0370  max mem: 6911
# Epoch: [2]  [240/478]  eta: 0:02:43  lr: 0.001000  loss: 0.0851 (0.0941)  loss_classifier: 0.0057 (0.0059)  loss_box_reg: 0.0138 (0.0164)  loss_mask: 0.0652 (0.0707)  loss_objectness: 0.0000 (0.0001)  loss_rpn_box_reg: 0.0008 (0.0010)  time: 0.6854  data: 0.0369  max mem: 6911
# Epoch: [2]  [250/478]  eta: 0:02:36  lr: 0.001000  loss: 0.0842 (0.0939)  loss_classifier: 0.0053 (0.0059)  loss_box_reg: 0.0135 (0.0163)  loss_mask: 0.0674 (0.0706)  loss_objectness: 0.0000 (0.0001)  loss_rpn_box_reg: 0.0007 (0.0010)  time: 0.6863  data: 0.0369  max mem: 6911
# Epoch: [2]  [260/478]  eta: 0:02:29  lr: 0.001000  loss: 0.0836 (0.0934)  loss_classifier: 0.0050 (0.0059)  loss_box_reg: 0.0127 (0.0162)  loss_mask: 0.0642 (0.0703)  loss_objectness: 0.0000 (0.0001)  loss_rpn_box_reg: 0.0005 (0.0010)  time: 0.6866  data: 0.0371  max mem: 6911
# Epoch: [2]  [270/478]  eta: 0:02:22  lr: 0.001000  loss: 0.0838 (0.0933)  loss_classifier: 0.0048 (0.0058)  loss_box_reg: 0.0134 (0.0161)  loss_mask: 0.0644 (0.0703)  loss_objectness: 0.0000 (0.0001)  loss_rpn_box_reg: 0.0005 (0.0010)  time: 0.6860  data: 0.0372  max mem: 6911
# Epoch: [2]  [280/478]  eta: 0:02:15  lr: 0.001000  loss: 0.0873 (0.0931)  loss_classifier: 0.0053 (0.0058)  loss_box_reg: 0.0134 (0.0160)  loss_mask: 0.0683 (0.0702)  loss_objectness: 0.0000 (0.0001)  loss_rpn_box_reg: 0.0008 (0.0010)  time: 0.6856  data: 0.0373  max mem: 6911
# Epoch: [2]  [290/478]  eta: 0:02:08  lr: 0.001000  loss: 0.0859 (0.0929)  loss_classifier: 0.0059 (0.0058)  loss_box_reg: 0.0114 (0.0159)  loss_mask: 0.0674 (0.0701)  loss_objectness: 0.0000 (0.0001)  loss_rpn_box_reg: 0.0007 (0.0010)  time: 0.6856  data: 0.0370  max mem: 6911
# Epoch: [2]  [300/478]  eta: 0:02:02  lr: 0.001000  loss: 0.0847 (0.0927)  loss_classifier: 0.0056 (0.0058)  loss_box_reg: 0.0118 (0.0158)  loss_mask: 0.0659 (0.0700)  loss_objectness: 0.0000 (0.0001)  loss_rpn_box_reg: 0.0006 (0.0010)  time: 0.6850  data: 0.0367  max mem: 6911
# Epoch: [2]  [310/478]  eta: 0:01:55  lr: 0.001000  loss: 0.0918 (0.0931)  loss_classifier: 0.0060 (0.0059)  loss_box_reg: 0.0137 (0.0158)  loss_mask: 0.0680 (0.0703)  loss_objectness: 0.0000 (0.0001)  loss_rpn_box_reg: 0.0006 (0.0010)  time: 0.6862  data: 0.0369  max mem: 6911
# Epoch: [2]  [320/478]  eta: 0:01:48  lr: 0.001000  loss: 0.0959 (0.0931)  loss_classifier: 0.0068 (0.0059)  loss_box_reg: 0.0164 (0.0159)  loss_mask: 0.0699 (0.0702)  loss_objectness: 0.0000 (0.0001)  loss_rpn_box_reg: 0.0006 (0.0010)  time: 0.6879  data: 0.0369  max mem: 6911
# Epoch: [2]  [330/478]  eta: 0:01:41  lr: 0.001000  loss: 0.0872 (0.0930)  loss_classifier: 0.0060 (0.0060)  loss_box_reg: 0.0152 (0.0158)  loss_mask: 0.0648 (0.0702)  loss_objectness: 0.0000 (0.0001)  loss_rpn_box_reg: 0.0007 (0.0010)  time: 0.6872  data: 0.0368  max mem: 6911
# Epoch: [2]  [340/478]  eta: 0:01:34  lr: 0.001000  loss: 0.0871 (0.0929)  loss_classifier: 0.0061 (0.0060)  loss_box_reg: 0.0143 (0.0158)  loss_mask: 0.0663 (0.0701)  loss_objectness: 0.0000 (0.0001)  loss_rpn_box_reg: 0.0006 (0.0010)  time: 0.6863  data: 0.0369  max mem: 6911
# Epoch: [2]  [350/478]  eta: 0:01:27  lr: 0.001000  loss: 0.0898 (0.0928)  loss_classifier: 0.0061 (0.0060)  loss_box_reg: 0.0143 (0.0158)  loss_mask: 0.0674 (0.0700)  loss_objectness: 0.0000 (0.0001)  loss_rpn_box_reg: 0.0006 (0.0010)  time: 0.6864  data: 0.0368  max mem: 6911
# Epoch: [2]  [360/478]  eta: 0:01:20  lr: 0.001000  loss: 0.0898 (0.0927)  loss_classifier: 0.0051 (0.0059)  loss_box_reg: 0.0144 (0.0157)  loss_mask: 0.0679 (0.0700)  loss_objectness: 0.0000 (0.0001)  loss_rpn_box_reg: 0.0008 (0.0010)  time: 0.6862  data: 0.0371  max mem: 6911
# Epoch: [2]  [370/478]  eta: 0:01:14  lr: 0.001000  loss: 0.0878 (0.0926)  loss_classifier: 0.0051 (0.0059)  loss_box_reg: 0.0138 (0.0157)  loss_mask: 0.0680 (0.0700)  loss_objectness: 0.0000 (0.0001)  loss_rpn_box_reg: 0.0008 (0.0010)  time: 0.6864  data: 0.0373  max mem: 6911
# Epoch: [2]  [380/478]  eta: 0:01:07  lr: 0.001000  loss: 0.0888 (0.0925)  loss_classifier: 0.0055 (0.0059)  loss_box_reg: 0.0127 (0.0156)  loss_mask: 0.0680 (0.0699)  loss_objectness: 0.0000 (0.0001)  loss_rpn_box_reg: 0.0006 (0.0009)  time: 0.6871  data: 0.0369  max mem: 6911
# Epoch: [2]  [390/478]  eta: 0:01:00  lr: 0.001000  loss: 0.0877 (0.0923)  loss_classifier: 0.0055 (0.0059)  loss_box_reg: 0.0133 (0.0156)  loss_mask: 0.0656 (0.0698)  loss_objectness: 0.0000 (0.0001)  loss_rpn_box_reg: 0.0005 (0.0009)  time: 0.6866  data: 0.0367  max mem: 6911
# Epoch: [2]  [400/478]  eta: 0:00:53  lr: 0.001000  loss: 0.0852 (0.0922)  loss_classifier: 0.0050 (0.0059)  loss_box_reg: 0.0128 (0.0156)  loss_mask: 0.0656 (0.0697)  loss_objectness: 0.0000 (0.0001)  loss_rpn_box_reg: 0.0005 (0.0009)  time: 0.6857  data: 0.0369  max mem: 6911
# Epoch: [2]  [410/478]  eta: 0:00:46  lr: 0.001000  loss: 0.0856 (0.0920)  loss_classifier: 0.0050 (0.0059)  loss_box_reg: 0.0126 (0.0155)  loss_mask: 0.0666 (0.0697)  loss_objectness: 0.0000 (0.0001)  loss_rpn_box_reg: 0.0005 (0.0009)  time: 0.6851  data: 0.0369  max mem: 6911
# Epoch: [2]  [420/478]  eta: 0:00:39  lr: 0.001000  loss: 0.0853 (0.0919)  loss_classifier: 0.0048 (0.0059)  loss_box_reg: 0.0136 (0.0155)  loss_mask: 0.0660 (0.0696)  loss_objectness: 0.0000 (0.0001)  loss_rpn_box_reg: 0.0007 (0.0009)  time: 0.6865  data: 0.0368  max mem: 6911
# Epoch: [2]  [430/478]  eta: 0:00:32  lr: 0.001000  loss: 0.0826 (0.0919)  loss_classifier: 0.0048 (0.0059)  loss_box_reg: 0.0139 (0.0155)  loss_mask: 0.0641 (0.0695)  loss_objectness: 0.0000 (0.0001)  loss_rpn_box_reg: 0.0006 (0.0009)  time: 0.6879  data: 0.0368  max mem: 6911
# Epoch: [2]  [440/478]  eta: 0:00:26  lr: 0.001000  loss: 0.0877 (0.0918)  loss_classifier: 0.0058 (0.0059)  loss_box_reg: 0.0133 (0.0155)  loss_mask: 0.0642 (0.0695)  loss_objectness: 0.0000 (0.0001)  loss_rpn_box_reg: 0.0006 (0.0009)  time: 0.6877  data: 0.0371  max mem: 6911
# Epoch: [2]  [450/478]  eta: 0:00:19  lr: 0.001000  loss: 0.0877 (0.0918)  loss_classifier: 0.0053 (0.0058)  loss_box_reg: 0.0157 (0.0155)  loss_mask: 0.0667 (0.0694)  loss_objectness: 0.0000 (0.0001)  loss_rpn_box_reg: 0.0006 (0.0009)  time: 0.6874  data: 0.0371  max mem: 6911
# Epoch: [2]  [460/478]  eta: 0:00:12  lr: 0.001000  loss: 0.0867 (0.0916)  loss_classifier: 0.0046 (0.0058)  loss_box_reg: 0.0138 (0.0154)  loss_mask: 0.0667 (0.0694)  loss_objectness: 0.0000 (0.0001)  loss_rpn_box_reg: 0.0007 (0.0009)  time: 0.6867  data: 0.0368  max mem: 6911
# Epoch: [2]  [470/478]  eta: 0:00:05  lr: 0.001000  loss: 0.0851 (0.0915)  loss_classifier: 0.0046 (0.0058)  loss_box_reg: 0.0119 (0.0153)  loss_mask: 0.0658 (0.0693)  loss_objectness: 0.0000 (0.0001)  loss_rpn_box_reg: 0.0007 (0.0009)  time: 0.6846  data: 0.0366  max mem: 6911
# Epoch: [2]  [477/478]  eta: 0:00:00  lr: 0.001000  loss: 0.0868 (0.0919)  loss_classifier: 0.0056 (0.0060)  loss_box_reg: 0.0127 (0.0154)  loss_mask: 0.0668 (0.0696)  loss_objectness: 0.0000 (0.0001)  loss_rpn_box_reg: 0.0007 (0.0009)  time: 0.6547  data: 0.0353  max mem: 6911
# Epoch: [2] Total time: 0:05:27 (0.6847 s / it)
# Epoch: [3]  [  0/478]  eta: 0:05:27  lr: 0.001000  loss: 0.1127 (0.1127)  loss_classifier: 0.0058 (0.0058)  loss_box_reg: 0.0226 (0.0226)  loss_mask: 0.0837 (0.0837)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0007 (0.0007)  time: 0.6855  data: 0.0340  max mem: 6911
# Epoch: [3]  [ 10/478]  eta: 0:05:21  lr: 0.001000  loss: 0.1110 (0.1109)  loss_classifier: 0.0081 (0.0082)  loss_box_reg: 0.0224 (0.0214)  loss_mask: 0.0799 (0.0802)  loss_objectness: 0.0000 (0.0001)  loss_rpn_box_reg: 0.0010 (0.0011)  time: 0.6879  data: 0.0367  max mem: 6911
# Epoch: [3]  [ 20/478]  eta: 0:05:13  lr: 0.001000  loss: 0.1042 (0.1033)  loss_classifier: 0.0068 (0.0071)  loss_box_reg: 0.0188 (0.0192)  loss_mask: 0.0750 (0.0759)  loss_objectness: 0.0000 (0.0001)  loss_rpn_box_reg: 0.0010 (0.0011)  time: 0.6856  data: 0.0367  max mem: 6911
# Epoch: [3]  [ 30/478]  eta: 0:05:06  lr: 0.001000  loss: 0.0911 (0.0987)  loss_classifier: 0.0056 (0.0066)  loss_box_reg: 0.0147 (0.0173)  loss_mask: 0.0690 (0.0736)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0009 (0.0011)  time: 0.6836  data: 0.0368  max mem: 6911
# Epoch: [3]  [ 40/478]  eta: 0:04:59  lr: 0.001000  loss: 0.0866 (0.0959)  loss_classifier: 0.0053 (0.0063)  loss_box_reg: 0.0133 (0.0163)  loss_mask: 0.0664 (0.0723)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0007 (0.0010)  time: 0.6838  data: 0.0371  max mem: 6911
# Epoch: [3]  [ 50/478]  eta: 0:04:53  lr: 0.001000  loss: 0.0861 (0.0955)  loss_classifier: 0.0048 (0.0061)  loss_box_reg: 0.0120 (0.0159)  loss_mask: 0.0684 (0.0726)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0007 (0.0010)  time: 0.6838  data: 0.0367  max mem: 6911
# Epoch: [3]  [ 60/478]  eta: 0:04:46  lr: 0.001000  loss: 0.0874 (0.0950)  loss_classifier: 0.0048 (0.0060)  loss_box_reg: 0.0122 (0.0156)  loss_mask: 0.0701 (0.0725)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0006 (0.0009)  time: 0.6840  data: 0.0372  max mem: 6911
# Epoch: [3]  [ 70/478]  eta: 0:04:39  lr: 0.001000  loss: 0.0915 (0.0947)  loss_classifier: 0.0061 (0.0060)  loss_box_reg: 0.0148 (0.0158)  loss_mask: 0.0700 (0.0720)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0007 (0.0009)  time: 0.6853  data: 0.0372  max mem: 6911
# Epoch: [3]  [ 80/478]  eta: 0:04:32  lr: 0.001000  loss: 0.0905 (0.0942)  loss_classifier: 0.0057 (0.0060)  loss_box_reg: 0.0151 (0.0157)  loss_mask: 0.0660 (0.0715)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0007 (0.0009)  time: 0.6853  data: 0.0365  max mem: 6911
# Epoch: [3]  [ 90/478]  eta: 0:04:25  lr: 0.001000  loss: 0.0897 (0.0936)  loss_classifier: 0.0058 (0.0061)  loss_box_reg: 0.0144 (0.0156)  loss_mask: 0.0659 (0.0710)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0008 (0.0009)  time: 0.6845  data: 0.0365  max mem: 6911
# Epoch: [3]  [100/478]  eta: 0:04:18  lr: 0.001000  loss: 0.0897 (0.0941)  loss_classifier: 0.0062 (0.0061)  loss_box_reg: 0.0155 (0.0158)  loss_mask: 0.0659 (0.0713)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0008 (0.0009)  time: 0.6857  data: 0.0366  max mem: 6911
# Epoch: [3]  [110/478]  eta: 0:04:12  lr: 0.001000  loss: 0.0883 (0.0936)  loss_classifier: 0.0055 (0.0060)  loss_box_reg: 0.0147 (0.0156)  loss_mask: 0.0668 (0.0711)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0008 (0.0009)  time: 0.6860  data: 0.0368  max mem: 6911
# Epoch: [3]  [120/478]  eta: 0:04:05  lr: 0.001000  loss: 0.0873 (0.0935)  loss_classifier: 0.0053 (0.0060)  loss_box_reg: 0.0138 (0.0156)  loss_mask: 0.0671 (0.0709)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0008 (0.0009)  time: 0.6885  data: 0.0367  max mem: 6911
# Epoch: [3]  [130/478]  eta: 0:03:58  lr: 0.001000  loss: 0.0919 (0.0934)  loss_classifier: 0.0059 (0.0060)  loss_box_reg: 0.0155 (0.0156)  loss_mask: 0.0686 (0.0709)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0007 (0.0009)  time: 0.6926  data: 0.0377  max mem: 6911
# Epoch: [3]  [140/478]  eta: 0:03:51  lr: 0.001000  loss: 0.0915 (0.0932)  loss_classifier: 0.0059 (0.0060)  loss_box_reg: 0.0150 (0.0156)  loss_mask: 0.0684 (0.0707)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0006 (0.0009)  time: 0.6915  data: 0.0378  max mem: 6911
# Epoch: [3]  [150/478]  eta: 0:03:45  lr: 0.001000  loss: 0.0907 (0.0939)  loss_classifier: 0.0059 (0.0062)  loss_box_reg: 0.0159 (0.0159)  loss_mask: 0.0668 (0.0709)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0008 (0.0009)  time: 0.6898  data: 0.0365  max mem: 6911
# Epoch: [3]  [160/478]  eta: 0:03:38  lr: 0.001000  loss: 0.0872 (0.0935)  loss_classifier: 0.0057 (0.0061)  loss_box_reg: 0.0142 (0.0157)  loss_mask: 0.0665 (0.0707)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0008 (0.0009)  time: 0.6903  data: 0.0365  max mem: 6911
# Epoch: [3]  [170/478]  eta: 0:03:31  lr: 0.001000  loss: 0.0869 (0.0931)  loss_classifier: 0.0051 (0.0061)  loss_box_reg: 0.0130 (0.0156)  loss_mask: 0.0668 (0.0705)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0006 (0.0009)  time: 0.6854  data: 0.0366  max mem: 6911
# Epoch: [3]  [180/478]  eta: 0:03:24  lr: 0.001000  loss: 0.0845 (0.0927)  loss_classifier: 0.0051 (0.0060)  loss_box_reg: 0.0130 (0.0155)  loss_mask: 0.0650 (0.0703)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0005 (0.0008)  time: 0.6821  data: 0.0366  max mem: 6911
# Epoch: [3]  [190/478]  eta: 0:03:17  lr: 0.001000  loss: 0.0843 (0.0926)  loss_classifier: 0.0051 (0.0060)  loss_box_reg: 0.0128 (0.0154)  loss_mask: 0.0647 (0.0703)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0005 (0.0008)  time: 0.6836  data: 0.0366  max mem: 6911
# Epoch: [3]  [200/478]  eta: 0:03:10  lr: 0.001000  loss: 0.0823 (0.0922)  loss_classifier: 0.0048 (0.0060)  loss_box_reg: 0.0116 (0.0152)  loss_mask: 0.0658 (0.0702)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0005 (0.0008)  time: 0.6845  data: 0.0366  max mem: 6911
# Epoch: [3]  [210/478]  eta: 0:03:03  lr: 0.001000  loss: 0.0809 (0.0917)  loss_classifier: 0.0048 (0.0059)  loss_box_reg: 0.0110 (0.0150)  loss_mask: 0.0663 (0.0700)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0005 (0.0008)  time: 0.6857  data: 0.0368  max mem: 6911
# ...
# Epoch: [8]  [460/478]  eta: 0:00:12  lr: 0.000500  loss: 0.0711 (0.0739)  loss_classifier: 0.0031 (0.0038)  loss_box_reg: 0.0069 (0.0076)  loss_mask: 0.0605 (0.0622)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0003 (0.0003)  time: 0.6835  data: 0.0368  max mem: 6911
# Epoch: [8]  [470/478]  eta: 0:00:05  lr: 0.000500  loss: 0.0707 (0.0740)  loss_classifier: 0.0031 (0.0037)  loss_box_reg: 0.0076 (0.0076)  loss_mask: 0.0605 (0.0623)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0003 (0.0003)  time: 0.6845  data: 0.0369  max mem: 6911
# Epoch: [8]  [477/478]  eta: 0:00:00  lr: 0.000500  loss: 0.0717 (0.0740)  loss_classifier: 0.0033 (0.0037)  loss_box_reg: 0.0077 (0.0076)  loss_mask: 0.0619 (0.0623)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0003 (0.0003)  time: 0.6555  data: 0.0356  max mem: 6911
# Epoch: [8] Total time: 0:05:26 (0.6830 s / it)
# Epoch: [9]  [  0/478]  eta: 0:05:24  lr: 0.000500  loss: 0.0647 (0.0647)  loss_classifier: 0.0025 (0.0025)  loss_box_reg: 0.0057 (0.0057)  loss_mask: 0.0563 (0.0563)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0002 (0.0002)  time: 0.6798  data: 0.0355  max mem: 6911
# Epoch: [9]  [ 10/478]  eta: 0:05:20  lr: 0.000500  loss: 0.0735 (0.0778)  loss_classifier: 0.0036 (0.0036)  loss_box_reg: 0.0090 (0.0094)  loss_mask: 0.0619 (0.0644)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0003 (0.0004)  time: 0.6849  data: 0.0376  max mem: 6911
# Epoch: [9]  [ 20/478]  eta: 0:05:13  lr: 0.000500  loss: 0.0735 (0.0762)  loss_classifier: 0.0036 (0.0035)  loss_box_reg: 0.0081 (0.0085)  loss_mask: 0.0619 (0.0639)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0003 (0.0004)  time: 0.6847  data: 0.0373  max mem: 6911
# Epoch: [9]  [ 30/478]  eta: 0:05:06  lr: 0.000500  loss: 0.0718 (0.0754)  loss_classifier: 0.0032 (0.0034)  loss_box_reg: 0.0071 (0.0082)  loss_mask: 0.0622 (0.0634)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0003 (0.0004)  time: 0.6836  data: 0.0367  max mem: 6911
# Epoch: [9]  [ 40/478]  eta: 0:04:59  lr: 0.000500  loss: 0.0725 (0.0757)  loss_classifier: 0.0032 (0.0035)  loss_box_reg: 0.0072 (0.0082)  loss_mask: 0.0622 (0.0636)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0003 (0.0004)  time: 0.6823  data: 0.0369  max mem: 6911
# Epoch: [9]  [ 50/478]  eta: 0:04:52  lr: 0.000500  loss: 0.0726 (0.0751)  loss_classifier: 0.0033 (0.0035)  loss_box_reg: 0.0072 (0.0080)  loss_mask: 0.0620 (0.0633)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0003 (0.0004)  time: 0.6833  data: 0.0371  max mem: 6911
# Epoch: [9]  [ 60/478]  eta: 0:04:45  lr: 0.000500  loss: 0.0721 (0.0747)  loss_classifier: 0.0038 (0.0036)  loss_box_reg: 0.0071 (0.0078)  loss_mask: 0.0610 (0.0629)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0003 (0.0004)  time: 0.6853  data: 0.0369  max mem: 6911
# Epoch: [9]  [ 70/478]  eta: 0:04:39  lr: 0.000500  loss: 0.0707 (0.0742)  loss_classifier: 0.0038 (0.0036)  loss_box_reg: 0.0068 (0.0077)  loss_mask: 0.0600 (0.0626)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0003 (0.0004)  time: 0.6856  data: 0.0370  max mem: 6911
# Epoch: [9]  [ 80/478]  eta: 0:04:32  lr: 0.000500  loss: 0.0707 (0.0743)  loss_classifier: 0.0036 (0.0036)  loss_box_reg: 0.0067 (0.0077)  loss_mask: 0.0603 (0.0626)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0004 (0.0004)  time: 0.6862  data: 0.0373  max mem: 6911
# Epoch: [9]  [ 90/478]  eta: 0:04:25  lr: 0.000500  loss: 0.0715 (0.0741)  loss_classifier: 0.0031 (0.0036)  loss_box_reg: 0.0076 (0.0078)  loss_mask: 0.0615 (0.0624)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0003 (0.0004)  time: 0.6855  data: 0.0371  max mem: 6911
# Epoch: [9]  [100/478]  eta: 0:04:18  lr: 0.000500  loss: 0.0708 (0.0739)  loss_classifier: 0.0037 (0.0036)  loss_box_reg: 0.0075 (0.0077)  loss_mask: 0.0601 (0.0623)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0003 (0.0003)  time: 0.6861  data: 0.0369  max mem: 6911
# Epoch: [9]  [110/478]  eta: 0:04:11  lr: 0.000500  loss: 0.0695 (0.0734)  loss_classifier: 0.0031 (0.0035)  loss_box_reg: 0.0063 (0.0075)  loss_mask: 0.0600 (0.0620)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0002 (0.0003)  time: 0.6855  data: 0.0368  max mem: 6911
# Epoch: [9]  [120/478]  eta: 0:04:05  lr: 0.000500  loss: 0.0690 (0.0732)  loss_classifier: 0.0028 (0.0035)  loss_box_reg: 0.0062 (0.0075)  loss_mask: 0.0591 (0.0619)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0002 (0.0003)  time: 0.6833  data: 0.0369  max mem: 6911
# Epoch: [9]  [130/478]  eta: 0:03:58  lr: 0.000500  loss: 0.0732 (0.0747)  loss_classifier: 0.0037 (0.0036)  loss_box_reg: 0.0064 (0.0076)  loss_mask: 0.0613 (0.0631)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0003 (0.0003)  time: 0.6843  data: 0.0370  max mem: 6911
# Epoch: [9]  [140/478]  eta: 0:03:51  lr: 0.000500  loss: 0.0761 (0.0748)  loss_classifier: 0.0040 (0.0037)  loss_box_reg: 0.0072 (0.0077)  loss_mask: 0.0621 (0.0630)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0003 (0.0003)  time: 0.6853  data: 0.0370  max mem: 6911
# Epoch: [9]  [150/478]  eta: 0:03:44  lr: 0.000500  loss: 0.0737 (0.0747)  loss_classifier: 0.0040 (0.0037)  loss_box_reg: 0.0072 (0.0077)  loss_mask: 0.0617 (0.0630)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0003 (0.0003)  time: 0.6838  data: 0.0371  max mem: 6911
# Epoch: [9]  [160/478]  eta: 0:03:37  lr: 0.000500  loss: 0.0719 (0.0747)  loss_classifier: 0.0037 (0.0038)  loss_box_reg: 0.0068 (0.0077)  loss_mask: 0.0611 (0.0630)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0002 (0.0003)  time: 0.6829  data: 0.0369  max mem: 6911
# Epoch: [9]  [170/478]  eta: 0:03:30  lr: 0.000500  loss: 0.0709 (0.0747)  loss_classifier: 0.0036 (0.0037)  loss_box_reg: 0.0070 (0.0077)  loss_mask: 0.0603 (0.0629)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0003 (0.0003)  time: 0.6839  data: 0.0367  max mem: 6911
# Epoch: [9]  [180/478]  eta: 0:03:23  lr: 0.000500  loss: 0.0734 (0.0745)  loss_classifier: 0.0031 (0.0037)  loss_box_reg: 0.0073 (0.0076)  loss_mask: 0.0604 (0.0628)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0003 (0.0003)  time: 0.6842  data: 0.0367  max mem: 6911
# Epoch: [9]  [190/478]  eta: 0:03:17  lr: 0.000500  loss: 0.0732 (0.0745)  loss_classifier: 0.0035 (0.0037)  loss_box_reg: 0.0065 (0.0076)  loss_mask: 0.0606 (0.0628)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0003 (0.0003)  time: 0.6829  data: 0.0368  max mem: 6911
# Epoch: [9]  [200/478]  eta: 0:03:10  lr: 0.000500  loss: 0.0731 (0.0746)  loss_classifier: 0.0037 (0.0037)  loss_box_reg: 0.0065 (0.0076)  loss_mask: 0.0615 (0.0629)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0003 (0.0003)  time: 0.6816  data: 0.0366  max mem: 6911
# Epoch: [9]  [210/478]  eta: 0:03:03  lr: 0.000500  loss: 0.0711 (0.0744)  loss_classifier: 0.0031 (0.0037)  loss_box_reg: 0.0066 (0.0076)  loss_mask: 0.0603 (0.0627)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0003 (0.0003)  time: 0.6826  data: 0.0368  max mem: 6911
# Epoch: [9]  [220/478]  eta: 0:02:56  lr: 0.000500  loss: 0.0695 (0.0742)  loss_classifier: 0.0031 (0.0037)  loss_box_reg: 0.0066 (0.0076)  loss_mask: 0.0601 (0.0626)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0002 (0.0003)  time: 0.6823  data: 0.0370  max mem: 6911
# Epoch: [9]  [230/478]  eta: 0:02:49  lr: 0.000500  loss: 0.0703 (0.0741)  loss_classifier: 0.0035 (0.0037)  loss_box_reg: 0.0062 (0.0075)  loss_mask: 0.0600 (0.0625)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0002 (0.0003)  time: 0.6826  data: 0.0370  max mem: 6911
# Epoch: [9]  [240/478]  eta: 0:02:42  lr: 0.000500  loss: 0.0706 (0.0740)  loss_classifier: 0.0034 (0.0037)  loss_box_reg: 0.0062 (0.0075)  loss_mask: 0.0599 (0.0625)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0003 (0.0003)  time: 0.6845  data: 0.0369  max mem: 6911
# Epoch: [9]  [250/478]  eta: 0:02:35  lr: 0.000500  loss: 0.0705 (0.0739)  loss_classifier: 0.0031 (0.0037)  loss_box_reg: 0.0066 (0.0074)  loss_mask: 0.0609 (0.0625)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0003 (0.0003)  time: 0.6856  data: 0.0370  max mem: 6911
# Epoch: [9]  [260/478]  eta: 0:02:29  lr: 0.000500  loss: 0.0713 (0.0739)  loss_classifier: 0.0030 (0.0036)  loss_box_reg: 0.0068 (0.0074)  loss_mask: 0.0622 (0.0625)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0003 (0.0003)  time: 0.6864  data: 0.0370  max mem: 6911
# Epoch: [9]  [270/478]  eta: 0:02:22  lr: 0.000500  loss: 0.0749 (0.0740)  loss_classifier: 0.0035 (0.0037)  loss_box_reg: 0.0077 (0.0075)  loss_mask: 0.0632 (0.0626)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0003 (0.0003)  time: 0.6853  data: 0.0368  max mem: 6911
# Epoch: [9]  [280/478]  eta: 0:02:15  lr: 0.000500  loss: 0.0760 (0.0742)  loss_classifier: 0.0036 (0.0037)  loss_box_reg: 0.0081 (0.0075)  loss_mask: 0.0647 (0.0627)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0003 (0.0003)  time: 0.6835  data: 0.0367  max mem: 6911
# Epoch: [9]  [290/478]  eta: 0:02:08  lr: 0.000500  loss: 0.0753 (0.0742)  loss_classifier: 0.0037 (0.0037)  loss_box_reg: 0.0081 (0.0075)  loss_mask: 0.0621 (0.0626)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0003 (0.0003)  time: 0.6840  data: 0.0366  max mem: 6911
# Epoch: [9]  [300/478]  eta: 0:02:01  lr: 0.000500  loss: 0.0737 (0.0741)  loss_classifier: 0.0038 (0.0037)  loss_box_reg: 0.0077 (0.0075)  loss_mask: 0.0616 (0.0626)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0003 (0.0003)  time: 0.6840  data: 0.0366  max mem: 6911
# Epoch: [9]  [310/478]  eta: 0:01:54  lr: 0.000500  loss: 0.0713 (0.0741)  loss_classifier: 0.0034 (0.0037)  loss_box_reg: 0.0066 (0.0075)  loss_mask: 0.0608 (0.0625)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0003 (0.0003)  time: 0.6835  data: 0.0367  max mem: 6911
# Epoch: [9]  [320/478]  eta: 0:01:48  lr: 0.000500  loss: 0.0718 (0.0741)  loss_classifier: 0.0031 (0.0037)  loss_box_reg: 0.0074 (0.0075)  loss_mask: 0.0608 (0.0626)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0003 (0.0003)  time: 0.6829  data: 0.0368  max mem: 6911
# Epoch: [9]  [330/478]  eta: 0:01:41  lr: 0.000500  loss: 0.0719 (0.0740)  loss_classifier: 0.0030 (0.0037)  loss_box_reg: 0.0073 (0.0075)  loss_mask: 0.0602 (0.0625)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0003 (0.0003)  time: 0.6822  data: 0.0368  max mem: 6911
# Epoch: [9]  [340/478]  eta: 0:01:34  lr: 0.000500  loss: 0.0712 (0.0740)  loss_classifier: 0.0029 (0.0037)  loss_box_reg: 0.0071 (0.0075)  loss_mask: 0.0606 (0.0625)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0002 (0.0003)  time: 0.6826  data: 0.0370  max mem: 6911
# Epoch: [9]  [350/478]  eta: 0:01:27  lr: 0.000500  loss: 0.0741 (0.0742)  loss_classifier: 0.0033 (0.0037)  loss_box_reg: 0.0074 (0.0076)  loss_mask: 0.0615 (0.0626)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0002 (0.0003)  time: 0.6821  data: 0.0371  max mem: 6911
# Epoch: [9]  [360/478]  eta: 0:01:20  lr: 0.000500  loss: 0.0760 (0.0743)  loss_classifier: 0.0034 (0.0037)  loss_box_reg: 0.0082 (0.0076)  loss_mask: 0.0632 (0.0627)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0003 (0.0003)  time: 0.6818  data: 0.0370  max mem: 6911
# Epoch: [9]  [370/478]  eta: 0:01:13  lr: 0.000500  loss: 0.0761 (0.0745)  loss_classifier: 0.0036 (0.0037)  loss_box_reg: 0.0086 (0.0077)  loss_mask: 0.0629 (0.0628)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0003 (0.0003)  time: 0.6807  data: 0.0369  max mem: 6911
# Epoch: [9]  [380/478]  eta: 0:01:07  lr: 0.000500  loss: 0.0718 (0.0743)  loss_classifier: 0.0036 (0.0037)  loss_box_reg: 0.0073 (0.0077)  loss_mask: 0.0598 (0.0627)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0002 (0.0003)  time: 0.6805  data: 0.0366  max mem: 6911
# Epoch: [9]  [390/478]  eta: 0:01:00  lr: 0.000500  loss: 0.0683 (0.0742)  loss_classifier: 0.0031 (0.0036)  loss_box_reg: 0.0063 (0.0076)  loss_mask: 0.0593 (0.0626)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0002 (0.0003)  time: 0.6801  data: 0.0363  max mem: 6911
# Epoch: [9]  [400/478]  eta: 0:00:53  lr: 0.000500  loss: 0.0714 (0.0742)  loss_classifier: 0.0028 (0.0036)  loss_box_reg: 0.0063 (0.0076)  loss_mask: 0.0609 (0.0626)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0002 (0.0003)  time: 0.6795  data: 0.0364  max mem: 6911
# Epoch: [9]  [410/478]  eta: 0:00:46  lr: 0.000500  loss: 0.0694 (0.0741)  loss_classifier: 0.0028 (0.0036)  loss_box_reg: 0.0062 (0.0076)  loss_mask: 0.0596 (0.0626)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0002 (0.0003)  time: 0.6822  data: 0.0367  max mem: 6911
# Epoch: [9]  [420/478]  eta: 0:00:39  lr: 0.000500  loss: 0.0689 (0.0741)  loss_classifier: 0.0029 (0.0036)  loss_box_reg: 0.0065 (0.0076)  loss_mask: 0.0591 (0.0626)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0002 (0.0003)  time: 0.6863  data: 0.0368  max mem: 6911
# Epoch: [9]  [430/478]  eta: 0:00:32  lr: 0.000500  loss: 0.0705 (0.0741)  loss_classifier: 0.0032 (0.0036)  loss_box_reg: 0.0067 (0.0076)  loss_mask: 0.0606 (0.0626)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0002 (0.0003)  time: 0.6875  data: 0.0368  max mem: 6911
# Epoch: [9]  [440/478]  eta: 0:00:25  lr: 0.000500  loss: 0.0705 (0.0741)  loss_classifier: 0.0035 (0.0036)  loss_box_reg: 0.0075 (0.0076)  loss_mask: 0.0598 (0.0625)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0002 (0.0003)  time: 0.6873  data: 0.0369  max mem: 6911
# Epoch: [9]  [450/478]  eta: 0:00:19  lr: 0.000500  loss: 0.0716 (0.0740)  loss_classifier: 0.0041 (0.0037)  loss_box_reg: 0.0076 (0.0076)  loss_mask: 0.0598 (0.0625)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0002 (0.0003)  time: 0.6858  data: 0.0368  max mem: 6911
# Epoch: [9]  [460/478]  eta: 0:00:12  lr: 0.000500  loss: 0.0724 (0.0740)  loss_classifier: 0.0041 (0.0037)  loss_box_reg: 0.0074 (0.0076)  loss_mask: 0.0602 (0.0624)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0002 (0.0003)  time: 0.6829  data: 0.0367  max mem: 6911
# Epoch: [9]  [470/478]  eta: 0:00:05  lr: 0.000500  loss: 0.0706 (0.0739)  loss_classifier: 0.0034 (0.0037)  loss_box_reg: 0.0071 (0.0076)  loss_mask: 0.0600 (0.0624)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0002 (0.0003)  time: 0.6821  data: 0.0369  max mem: 6911
# Epoch: [9]  [477/478]  eta: 0:00:00  lr: 0.000500  loss: 0.0706 (0.0739)  loss_classifier: 0.0032 (0.0037)  loss_box_reg: 0.0071 (0.0075)  loss_mask: 0.0596 (0.0624)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0002 (0.0003)  time: 0.6531  data: 0.0353  max mem: 6911
# Epoch: [9] Total time: 0:05:26 (0.6826 s / it)
# Test:  [  0/120]  eta: 0:00:47  model_time: 0.2917 (0.2917)  time: 0.3956  data: 0.0988  max mem: 6911
# Test:  [100/120]  eta: 0:00:07  model_time: 0.2797 (0.2805)  time: 0.3887  data: 0.1054  max mem: 6911
# Test:  [119/120]  eta: 0:00:00  model_time: 0.2794 (0.2792)  time: 0.3765  data: 0.1011  max mem: 6911
# Test: Total time: 0:00:46 (0.3873 s / it)
# Averaged stats: model_time: 0.2794 (0.2792)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 train_model()
# ----> 2 load_and_test_model('final_model.pth')
#
# Cell In[4], line 52, in load_and_test_model(model_path)
#      50 dataset = ImageDataset()
#      51 sample_image, target = dataset[0]
# ---> 52 prediction = model([sample_image.to(model.device)])[0]
#      53 print(prediction)
#
# File c:\Users\Varadh\Desktop\NEU\CS5335-Robotic-Science-and-Systems\Project\CS5335-4610-Project\.venv\lib\site-packages\torch\nn\modules\module.py:1688, in Module.__getattr__(self, name)
#    1686     if name in modules:
#    1687         return modules[name]
# -> 1688 raise AttributeError(f"'{type(self).__name__}' object has no attribute '{name}'")
#
# AttributeError: 'MaskRCNN' object has no attribute 'device'

# %%
# import os
# import numpy as np
# from PIL import Image

# from tqdm import tqdm

# import torch
# from torch.utils.data import Dataset
# from torch.utils.data import DataLoader
# import torchvision.transforms as transforms
# from torchvision.transforms import functional as F

# from torchvision.models.detection import maskrcnn_resnet50_fpn
# from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
# from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor

# %%
# class FoodCanDataset(Dataset):
#     def __init__(self, root, transforms=None):
#         self.root = root
#         self.transforms = transforms
#         self.imgs = []
#         self.masks = []

#         # Load all files, filtering out non-image and mask files
#         all_files = os.listdir(root)
#         self.imgs = [os.path.join(root, f) for f in all_files if f.endswith('.png') and not f.endswith('_mask.png') and not f.endswith('_depth.png')]
#         self.masks = [f"{img[:-4]}_mask.png" for img in self.imgs]  # Corresponding mask for each image

#         print(f"Found {len(self.imgs)} images and {len(self.masks)} masks.")

#     def __getitem__(self, idx):
#         img_path = self.imgs[idx]
#         mask_path = self.masks[idx]

#         img = Image.open(img_path).convert("RGB")
#         mask = Image.open(mask_path)
#         mask = np.array(mask)  # Convert mask image to numpy array

#         # Process mask data
#         obj_ids = np.unique(mask)
#         obj_ids = obj_ids[1:]  # Remove the background

#         masks = mask == obj_ids[:, None, None]
#         num_objs = len(obj_ids)
#         boxes = []
#         for i in range(num_objs):
#             pos = np.where(masks[i])
#             xmin = np.min(pos[1])
#             xmax = np.max(pos[1])
#             ymin = np.min(pos[0])
#             ymax = np.max(pos[0])
#             boxes.append([xmin, ymin, xmax, ymax])

#         boxes = torch.as_tensor(boxes, dtype=torch.float32)
#         labels = torch.ones((num_objs,), dtype=torch.int64)
#         masks = torch.as_tensor(masks, dtype=torch.uint8)

#         image_id = torch.tensor([idx])
#         area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])
#         iscrowd = torch.zeros((num_objs,), dtype=torch.int32)

#         target = {
#             "boxes": boxes,
#             "labels": labels,
#             "masks": masks,
#             "image_id": image_id,
#             "area": area,
#             "iscrowd": iscrowd
#         }

#         if self.transforms:
#             img, target = self.transforms(img, target)

#         return img, target

#     def __len__(self):
#         return len(self.imgs)

# def get_transform():
#     def transform(img, target):
#         img = F.to_tensor(img)
#         return img, target
#     return transform

# %%
# def get_model_instance_segmentation(num_classes):
#     # Load an instance segmentation model pre-trained on COCO
#     model = maskrcnn_resnet50_fpn(pretrained=True)

#     # Freeze the backbone layers
#     for param in model.backbone.parameters():
#         param.requires_grad = False

#     # Replace the head of the model (which typically includes the classifier and box predictor)
#     in_features = model.roi_heads.box_predictor.cls_score.in_features
#     model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

#     in_features_mask = model.roi_heads.mask_predictor.conv5_mask.in_channels
#     hidden_layer = 256
#     model.roi_heads.mask_predictor = MaskRCNNPredictor(in_features_mask,
#                                                        hidden_layer,
#                                                        num_classes)

#     return model

# %%
# # Load the training and validation sets
# def get_transform():
#     transform = transforms.Compose([
#         transforms.ToTensor(),
#     ])
#     return transform

# train_dataset = FoodCanDataset('.\\rgbd-dataset\\food_can\\', get_transform())
# val_dataset = FoodCanDataset('.\\rgbd-dataset\\food_can_val\\', get_transform())

# # Define training and validation data loaders
# train_loader = DataLoader(train_dataset, batch_size=2, shuffle=True, num_workers=28)
# val_loader = DataLoader(val_dataset, batch_size=2, shuffle=False, num_workers=28)

# device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
# print(f"Using {torch.cuda.get_device_name(device)}")
# num_classes = 2  # 1 class (food can) + background

# model = get_model_instance_segmentation(num_classes)
# model.to(device)

# # Parameters and optimizer
# params = [p for p in model.parameters() if p.requires_grad]
# optimizer = torch.optim.SGD(params, lr=0.005, momentum=0.9, weight_decay=0.0005)
# lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.1)

# # Number of epochs to train for
# num_epochs = 8

# for epoch in range(num_epochs):
#     model.train()
#     train_loop = tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs} (Train)")
#     i = 0
#     for images, targets in train_loader:
#         images = list(image.to(device) for image in images)
#         targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

#         loss_dict = model(images, targets)
#         losses = sum(loss for loss in loss_dict.values())

#         optimizer.zero_grad()
#         losses.backward()
#         optimizer.step()

#         if i % 10 == 0:
#             print(f"Iteration {i} of epoch {epoch} completed, Loss: {losses.item()}")
#         i += 1

#     # Update the learning rate
#     lr_scheduler.step()

#     # Evaluate the model on the validation set
#     model.eval()
#     val_loop = tqdm(val_loader, desc=f"Epoch {epoch+1}/{num_epochs} (Validate)")
#     with torch.no_grad():
#         for images, targets in val_loader:
#             images = list(image.to(device) for image in images)
#             targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
#             prediction = model(images, targets)  # Use model to predict
#             # Here, implement your method to evaluate the prediction

# model_path = 'ft_model.pth'
# torch.save(model, model_path)
# print("Model_saved")


# print("Training complete")
